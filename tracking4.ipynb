# %%
import cv2
from ultralytics import YOLO
from collections import defaultdict

# Call model
model = YOLO("yolo11n.pt")


# Print Total number of classes
class_list = model.names
print(class_list)


# open the video files
cap = cv2.VideoCapture("4.mp4")


# Define line positions for counting
line_y_red = 350 # Red line position
line_y_blue = line_y_red + 50 # Blue line position

# Variables to store counting and tracking information
counted_ids_red_to_blue = set()
counted_ids_blue_to_red = set()

# Dictionaries to count objects by class for each direction
count_red_to_blue = defaultdict(int) # Moving downwords
count_blue_to_red = defaultdict(int) # Moving upwards

# State dictionaries to track which line was crossed first
crossed_red_first = {}
crossed_blue_first = {}


# Loop through video frames

while cap.isOpened():
    print("1")
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO tracking on the frame
    results = model.track(frame, persist = True, # bytetrack.yaml
                          tracker="bytetrack.yaml", # botsort.yaml
                           save = True)
    print(results)


    # Ensure results are not empty
    if results[0].boxes.data is not None:

      # Get the detected boxes, their class indices, and track IDs
      boxes = results[0].boxes.xyxy.cpu()
      track_ids = results[0].boxes.id.int().cpu().tolist()
      class_indices = results[0].boxes.cls.int().cpu().tolist()
      confidence = results[0].boxes.conf.cpu()

      # Draw the line of the each frame
      cv2.line(frame, (70, line_y_red), (1200, line_y_red ), (0, 0, 255), 3)
      cv2.putText(frame, "Red Line", (20, line_y_red - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

      cv2.line(frame, (70, line_y_blue), (1200, line_y_blue), (255, 0, 0), 3)
      cv2.putText(frame, "Blue Line", (20, line_y_blue - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

      # Loop through each detected object
      for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidence):
        x1, y1, x2, y2 = map(int, box)

        cx = (x1 + x2) // 2 # Calculate the center point
        cy = (y1 + y2) // 2


        # Get the class name using the class index
        class_name = class_list[class_idx]

        # Draw a dot at the center and display the tracking ID and class name
        cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
        cv2.putText(frame, f"ID: {track_id} {class_name} {confidence[-1]:.2f}", (x1, y1 - 10),
        cv2.FONT_HERSHEY_COMPLEX, 0.6, (0, 255, 255), 2)
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)


        # check if the object crosse the red line
        if line_y_red - 3 <= cy <= line_y_red + 3:
          # Record that the object crossed the red line
          if track_id not in crossed_red_first:
            crossed_red_first[track_id] = True

        # check if the object crosses the blue line
        if line_y_blue - 3 <= cy <= line_y_blue + 3:
          # Record that the object crossed the blue line
          if track_id not in crossed_blue_first:
            crossed_blue_first[track_id] = True


        # Counting logic for downward direction (red -> blue)
        if track_id in crossed_red_first and track_id not in counted_ids_red_to_blue:
          if line_y_blue -5 <= cy <= line_y_blue + 5:
            count_red_to_blue[class_name] += 1
            counted_ids_red_to_blue.add(track_id)

        # Counting logic for upward direction (blue -> red)
        if track_id in crossed_blue_first and track_id not in counted_ids_blue_to_red:
          if line_y_red -5 <= cy <= line_y_red + 5:
            count_blue_to_red[class_name] += 1
            counted_ids_blue_to_red.add(track_id)

    # Display the counts on the frame
    y_offset = 30
    for class_name, count in count_red_to_blue.items():
      cv2.putText(frame, f"{class_name} (Down): {count}", (10, y_offset),
                  cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)
      y_offset += 30

    y_offset += 20 # Add spacing for upward counts
    for class_name, count in count_blue_to_red.items():
      cv2.putText(frame, f"{class_name} (Up): {count}", (10, y_offset),
                 cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0 ,255), 2, cv2.LINE_AA)
      y_offset += 30

     


    # Show the frame
    cv2.imshow("YOLO Object Tracking & Counting", frame)

    # Exit loop if 'ESC' key is pressed
    if cv2.waitKey(1) & 0xFF == 27:
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import cv2
# ----> 2 from ultralytics import YOLO
#       3 from collections import defaultdict
#       5 # Call model
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
count_blue_to_red
# Out:
# defaultdict(int, {})

# %%
count_red_to_blue
# Out:
# defaultdict(int, {'car': 9})

# %%
import cv2
import math
from ultralytics import YOLO
from collections import defaultdict

# Load YOLO model
model = YOLO("yolo11n.pt")

# Class list
class_list = model.names
print("Classes:", class_list)

# Open video file
cap = cv2.VideoCapture("4.mp4")
fps = cap.get(cv2.CAP_PROP_FPS)

# Pixel-to-meter calibration (adjust based on your camera setup)
PIXEL_TO_METER = 0.05  # 1 pixel = 0.05 m (example)

# Define line positions for counting
line_y_red = 350
line_y_blue = line_y_red + 50

# Tracking dictionaries
counted_ids_red_to_blue = set()
counted_ids_blue_to_red = set()
count_red_to_blue = defaultdict(int)
count_blue_to_red = defaultdict(int)
crossed_red_first = {}
crossed_blue_first = {}

# Speed tracking
prev_positions = {}  # {track_id: (cx, cy)}
speeds = {}          # {track_id: current_speed_kmh}

# Storage for results
results_list = []    # [[frame, id1, id2, speed1, speed2, distance], ...]

frame_no = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame_no += 1

    # Run YOLO tracker
    results = model.track(frame, persist=True, tracker="bytetrack.yaml")

    if results[0].boxes.data is not None:
        boxes = results[0].boxes.xyxy.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()
        class_indices = results[0].boxes.cls.int().cpu().tolist()
        confidence = results[0].boxes.conf.cpu()

        vehicle_positions = []

        # Draw counting lines
        cv2.line(frame, (70, line_y_red), (1200, line_y_red), (0, 0, 255), 3)
        cv2.putText(frame, "Red Line", (20, line_y_red - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)
        cv2.line(frame, (70, line_y_blue), (1200, line_y_blue), (255, 0, 0), 3)
        cv2.putText(frame, "Blue Line", (20, line_y_blue - 10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 255), 1)

        # Process each detected vehicle
        for box, track_id, class_idx, conf in zip(boxes, track_ids, class_indices, confidence):
            x1, y1, x2, y2 = map(int, box)
            cx = (x1 + x2) // 2
            cy = (y1 + y2) // 2
            class_name = class_list[class_idx]

            # --- Speed calculation ---
            if track_id in prev_positions:
                px, py = prev_positions[track_id]
                dist_pixels = math.sqrt((cx - px)**2 + (cy - py)**2)
                dist_meters = dist_pixels * PIXEL_TO_METER
                speed_mps = dist_meters * fps
                speed_kmh = speed_mps * 3.6
            else:
                speed_kmh = 0.0

            prev_positions[track_id] = (cx, cy)
            speeds[track_id] = speed_kmh

            vehicle_positions.append((track_id, cx, cy, speed_kmh, class_name))

            # Draw detections
            cv2.circle(frame, (cx, cy), 4, (0, 0, 255), -1)
            cv2.putText(frame, f"ID:{track_id} {class_name} {speed_kmh:.1f} km/h",
                        (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX,
                        0.6, (0, 255, 255), 2)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

            # --- Counting logic ---
            if line_y_red - 3 <= cy <= line_y_red + 3:
                if track_id not in crossed_red_first:
                    crossed_red_first[track_id] = True

            if line_y_blue - 3 <= cy <= line_y_blue + 3:
                if track_id not in crossed_blue_first:
                    crossed_blue_first[track_id] = True

            if track_id in crossed_red_first and track_id not in counted_ids_red_to_blue:
                if line_y_blue - 5 <= cy <= line_y_blue + 5:
                    count_red_to_blue[class_name] += 1
                    counted_ids_red_to_blue.add(track_id)

            if track_id in crossed_blue_first and track_id not in counted_ids_blue_to_red:
                if line_y_red - 5 <= cy <= line_y_red + 5:
                    count_blue_to_red[class_name] += 1
                    counted_ids_blue_to_red.add(track_id)

            # Hard braking threshold (20 km/h drop ek frame se dusre frame me)
            HARD_BRAKE_THRESHOLD = 20  

            # Initialize counter before loop
            hard_braking_events = 0  

            # Inside object loop
            if track_id in speeds:  
                prev_speed = speeds[track_id]  
                if prev_speed - speed_kmh > HARD_BRAKE_THRESHOLD:  
                    hard_braking_events += 1  


        # --- Distance calculation between vehicles ---
        for i in range(len(vehicle_positions)):
            for j in range(i + 1, len(vehicle_positions)):
                id1, x1, y1, v1, cname1 = vehicle_positions[i]
                id2, x2, y2, v2, cname2 = vehicle_positions[j]
                dist_pixels = math.sqrt((x1 - x2)**2 + (y1 - y2)**2)
                dist_meters = dist_pixels * PIXEL_TO_METER

                # Save results
                results_list.append([frame_no, id1, id2, v1, v2, dist_meters])

                tailgating_events = 0
                if dist_meters < 10:  # 10 meter se kam distance = tailgating
                    tailgating_events += 1
                    cv2.line(frame, (x1, y1), (x2, y2), (255, 255, 0), 2)
                    cv2.putText(frame, f"{dist_meters:.1f} m",
                    ((x1 + x2)//2, (y1 + y2)//2),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                    (200, 255, 0), 2)


                # Draw lines between close vehicles
                if dist_meters < 10:  # threshold = 10 meters
                    cv2.line(frame, (x1, y1), (x2, y2), (255, 255, 0), 2)
                    cv2.putText(frame, f"{dist_meters:.1f} m",
                                ((x1 + x2)//2, (y1 + y2)//2),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                                (200, 255, 0), 2)

    # Display counts
    y_offset = 30
    for class_name, count in count_red_to_blue.items():
        cv2.putText(frame, f"{class_name} (Down): {count}", (10, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        y_offset += 30

    y_offset += 20
    for class_name, count in count_blue_to_red.items():
        cv2.putText(frame, f"{class_name} (Up): {count}", (10, y_offset),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        y_offset += 30

    # Show frame
    cv2.imshow("YOLO Tracking with Speed & Distance", frame)

    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()

# Print results for verification
print("Results List (first 10 entries):")
for r in results_list[:10]:
    print(r)
# Out:
# Classes: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#
# 0: 384x640 8 cars, 2 buss, 1 truck, 154.9ms
# Speed: 4.2ms preprocess, 154.9ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 1 truck, 225.0ms
# Speed: 4.9ms preprocess, 225.0ms inference, 13.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 181.2ms
# Speed: 4.3ms preprocess, 181.2ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 145.5ms
# Speed: 3.8ms preprocess, 145.5ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 175.0ms
# Speed: 6.7ms preprocess, 175.0ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 150.0ms
# Speed: 4.6ms preprocess, 150.0ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 2 trucks, 132.5ms
# Speed: 4.2ms preprocess, 132.5ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 buss, 2 trucks, 119.0ms
# Speed: 5.4ms preprocess, 119.0ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 2 trucks, 118.1ms
# Speed: 3.7ms preprocess, 118.1ms inference, 10.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 2 trucks, 119.7ms
# Speed: 5.9ms preprocess, 119.7ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 truck, 109.2ms
# Speed: 4.7ms preprocess, 109.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 truck, 112.8ms
# Speed: 3.9ms preprocess, 112.8ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 2 buss, 1 truck, 136.9ms
# Speed: 4.1ms preprocess, 136.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 2 trucks, 120.1ms
# Speed: 5.7ms preprocess, 120.1ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 bus, 2 trucks, 117.5ms
# Speed: 4.3ms preprocess, 117.5ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 132.1ms
# Speed: 4.3ms preprocess, 132.1ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 132.1ms
# Speed: 4.6ms preprocess, 132.1ms inference, 10.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 149.9ms
# Speed: 5.5ms preprocess, 149.9ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 151.4ms
# Speed: 4.4ms preprocess, 151.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 128.6ms
# Speed: 4.7ms preprocess, 128.6ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 112.9ms
# Speed: 5.8ms preprocess, 112.9ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 130.9ms
# Speed: 4.4ms preprocess, 130.9ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 142.2ms
# Speed: 5.0ms preprocess, 142.2ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 107.8ms
# Speed: 4.9ms preprocess, 107.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 4 trucks, 115.4ms
# Speed: 3.9ms preprocess, 115.4ms inference, 8.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 3 trucks, 129.5ms
# Speed: 5.6ms preprocess, 129.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 123.1ms
# Speed: 4.6ms preprocess, 123.1ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 134.6ms
# Speed: 4.3ms preprocess, 134.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 121.7ms
# Speed: 4.4ms preprocess, 121.7ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 121.6ms
# Speed: 5.6ms preprocess, 121.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 94.4ms
# Speed: 5.3ms preprocess, 94.4ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 102.0ms
# Speed: 3.0ms preprocess, 102.0ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 112.9ms
# Speed: 3.7ms preprocess, 112.9ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 153.9ms
# Speed: 5.3ms preprocess, 153.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 126.6ms
# Speed: 4.3ms preprocess, 126.6ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 122.6ms
# Speed: 4.4ms preprocess, 122.6ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 2 trucks, 113.4ms
# Speed: 4.9ms preprocess, 113.4ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 120.3ms
# Speed: 4.1ms preprocess, 120.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 122.4ms
# Speed: 4.5ms preprocess, 122.4ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 112.0ms
# Speed: 4.3ms preprocess, 112.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 119.0ms
# Speed: 4.1ms preprocess, 119.0ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 buss, 1 truck, 122.4ms
# Speed: 5.0ms preprocess, 122.4ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 122.5ms
# Speed: 5.9ms preprocess, 122.5ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 110.4ms
# Speed: 4.6ms preprocess, 110.4ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 117.0ms
# Speed: 4.0ms preprocess, 117.0ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 127.5ms
# Speed: 4.6ms preprocess, 127.5ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 112.9ms
# Speed: 4.2ms preprocess, 112.9ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 118.5ms
# Speed: 3.8ms preprocess, 118.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 120.7ms
# Speed: 5.1ms preprocess, 120.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 2 trucks, 125.7ms
# Speed: 4.7ms preprocess, 125.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 112.7ms
# Speed: 4.0ms preprocess, 112.7ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 115.5ms
# Speed: 4.0ms preprocess, 115.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 126.7ms
# Speed: 3.7ms preprocess, 126.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 118.7ms
# Speed: 3.4ms preprocess, 118.7ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 118.8ms
# Speed: 3.6ms preprocess, 118.8ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 118.7ms
# Speed: 5.2ms preprocess, 118.7ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 123.8ms
# Speed: 3.3ms preprocess, 123.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 108.2ms
# Speed: 5.3ms preprocess, 108.2ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 125.9ms
# Speed: 3.5ms preprocess, 125.9ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 172.0ms
# Speed: 4.8ms preprocess, 172.0ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 167.4ms
# Speed: 4.5ms preprocess, 167.4ms inference, 10.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 171.9ms
# Speed: 5.7ms preprocess, 171.9ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 194.1ms
# Speed: 4.0ms preprocess, 194.1ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 186.8ms
# Speed: 5.9ms preprocess, 186.8ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 169.5ms
# Speed: 3.8ms preprocess, 169.5ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 3 trucks, 158.8ms
# Speed: 5.6ms preprocess, 158.8ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 158.3ms
# Speed: 4.1ms preprocess, 158.3ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 163.4ms
# Speed: 316.5ms preprocess, 163.4ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 161.6ms
# Speed: 3.8ms preprocess, 161.6ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 166.7ms
# Speed: 4.7ms preprocess, 166.7ms inference, 9.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 163.4ms
# Speed: 4.2ms preprocess, 163.4ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 178.4ms
# Speed: 5.9ms preprocess, 178.4ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 177.5ms
# Speed: 4.2ms preprocess, 177.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 172.0ms
# Speed: 4.4ms preprocess, 172.0ms inference, 8.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 171.3ms
# Speed: 5.0ms preprocess, 171.3ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 175.5ms
# Speed: 6.4ms preprocess, 175.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 179.0ms
# Speed: 6.6ms preprocess, 179.0ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 185.1ms
# Speed: 4.5ms preprocess, 185.1ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 2 trucks, 170.9ms
# Speed: 4.8ms preprocess, 170.9ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 143.0ms
# Speed: 5.2ms preprocess, 143.0ms inference, 8.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 157.2ms
# Speed: 4.9ms preprocess, 157.2ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 163.9ms
# Speed: 4.0ms preprocess, 163.9ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 192.4ms
# Speed: 4.8ms preprocess, 192.4ms inference, 11.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 185.6ms
# Speed: 6.0ms preprocess, 185.6ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 167.0ms
# Speed: 5.4ms preprocess, 167.0ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 164.9ms
# Speed: 5.1ms preprocess, 164.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 170.1ms
# Speed: 4.4ms preprocess, 170.1ms inference, 10.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 154.9ms
# Speed: 4.1ms preprocess, 154.9ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 162.2ms
# Speed: 5.2ms preprocess, 162.2ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 167.7ms
# Speed: 4.3ms preprocess, 167.7ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 167.4ms
# Speed: 4.6ms preprocess, 167.4ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 172.4ms
# Speed: 4.5ms preprocess, 172.4ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 155.6ms
# Speed: 4.9ms preprocess, 155.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 138.6ms
# Speed: 4.5ms preprocess, 138.6ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 146.4ms
# Speed: 3.7ms preprocess, 146.4ms inference, 7.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 152.8ms
# Speed: 3.7ms preprocess, 152.8ms inference, 7.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 152.0ms
# Speed: 4.3ms preprocess, 152.0ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 161.0ms
# Speed: 5.3ms preprocess, 161.0ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 157.0ms
# Speed: 4.6ms preprocess, 157.0ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 165.3ms
# Speed: 4.0ms preprocess, 165.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 164.3ms
# Speed: 3.8ms preprocess, 164.3ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.3ms
# Speed: 3.8ms preprocess, 143.3ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 171.7ms
# Speed: 4.0ms preprocess, 171.7ms inference, 9.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 177.8ms
# Speed: 4.8ms preprocess, 177.8ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 141.2ms
# Speed: 4.5ms preprocess, 141.2ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 159.7ms
# Speed: 6.0ms preprocess, 159.7ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 167.9ms
# Speed: 5.0ms preprocess, 167.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 155.9ms
# Speed: 3.7ms preprocess, 155.9ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 155.7ms
# Speed: 3.8ms preprocess, 155.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 158.3ms
# Speed: 4.4ms preprocess, 158.3ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 148.6ms
# Speed: 4.1ms preprocess, 148.6ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 159.2ms
# Speed: 4.4ms preprocess, 159.2ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 161.0ms
# Speed: 4.1ms preprocess, 161.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 147.6ms
# Speed: 4.2ms preprocess, 147.6ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 144.2ms
# Speed: 4.1ms preprocess, 144.2ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 157.4ms
# Speed: 5.1ms preprocess, 157.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 153.6ms
# Speed: 4.1ms preprocess, 153.6ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 166.9ms
# Speed: 5.3ms preprocess, 166.9ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 174.3ms
# Speed: 4.2ms preprocess, 174.3ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 3 trucks, 168.1ms
# Speed: 5.0ms preprocess, 168.1ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 169.8ms
# Speed: 5.5ms preprocess, 169.8ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 174.0ms
# Speed: 4.4ms preprocess, 174.0ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 183.0ms
# Speed: 4.4ms preprocess, 183.0ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 193.1ms
# Speed: 5.5ms preprocess, 193.1ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 183.1ms
# Speed: 6.1ms preprocess, 183.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 173.6ms
# Speed: 4.1ms preprocess, 173.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 175.5ms
# Speed: 5.3ms preprocess, 175.5ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 168.1ms
# Speed: 4.4ms preprocess, 168.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 184.6ms
# Speed: 5.7ms preprocess, 184.6ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 172.9ms
# Speed: 4.5ms preprocess, 172.9ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 169.9ms
# Speed: 5.4ms preprocess, 169.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 169.1ms
# Speed: 3.7ms preprocess, 169.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 144.0ms
# Speed: 4.5ms preprocess, 144.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 142.8ms
# Speed: 5.1ms preprocess, 142.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 152.1ms
# Speed: 3.8ms preprocess, 152.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 150.4ms
# Speed: 4.0ms preprocess, 150.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 167.4ms
# Speed: 4.4ms preprocess, 167.4ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 164.2ms
# Speed: 4.2ms preprocess, 164.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 140.6ms
# Speed: 4.2ms preprocess, 140.6ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 162.9ms
# Speed: 4.5ms preprocess, 162.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 169.4ms
# Speed: 4.6ms preprocess, 169.4ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 160.8ms
# Speed: 5.6ms preprocess, 160.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 164.2ms
# Speed: 4.1ms preprocess, 164.2ms inference, 9.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 186.5ms
# Speed: 5.1ms preprocess, 186.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 161.4ms
# Speed: 6.6ms preprocess, 161.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 131.5ms
# Speed: 5.4ms preprocess, 131.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 160.4ms
# Speed: 4.5ms preprocess, 160.4ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 143.0ms
# Speed: 4.2ms preprocess, 143.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 122.1ms
# Speed: 4.9ms preprocess, 122.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 151.8ms
# Speed: 4.6ms preprocess, 151.8ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 trucks, 156.8ms
# Speed: 5.1ms preprocess, 156.8ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 143.8ms
# Speed: 5.5ms preprocess, 143.8ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 158.3ms
# Speed: 4.0ms preprocess, 158.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 142.9ms
# Speed: 5.6ms preprocess, 142.9ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 106.5ms
# Speed: 3.8ms preprocess, 106.5ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 110.2ms
# Speed: 3.2ms preprocess, 110.2ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 118.2ms
# Speed: 5.5ms preprocess, 118.2ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 131.7ms
# Speed: 5.2ms preprocess, 131.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 132.1ms
# Speed: 3.5ms preprocess, 132.1ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 152.1ms
# Speed: 4.0ms preprocess, 152.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 160.4ms
# Speed: 3.8ms preprocess, 160.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 104.7ms
# Speed: 4.0ms preprocess, 104.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 101.7ms
# Speed: 4.2ms preprocess, 101.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 117.5ms
# Speed: 5.0ms preprocess, 117.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 128.9ms
# Speed: 3.8ms preprocess, 128.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 103.0ms
# Speed: 3.7ms preprocess, 103.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 135.3ms
# Speed: 3.6ms preprocess, 135.3ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 155.0ms
# Speed: 5.2ms preprocess, 155.0ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 114.7ms
# Speed: 4.2ms preprocess, 114.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 130.5ms
# Speed: 4.6ms preprocess, 130.5ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 160.0ms
# Speed: 4.7ms preprocess, 160.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 139.1ms
# Speed: 3.9ms preprocess, 139.1ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 116.0ms
# Speed: 3.6ms preprocess, 116.0ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 4 trucks, 128.6ms
# Speed: 3.9ms preprocess, 128.6ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 149.5ms
# Speed: 3.6ms preprocess, 149.5ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 116.1ms
# Speed: 3.6ms preprocess, 116.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 123.5ms
# Speed: 3.6ms preprocess, 123.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 148.4ms
# Speed: 4.9ms preprocess, 148.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 118.0ms
# Speed: 5.0ms preprocess, 118.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 108.2ms
# Speed: 3.2ms preprocess, 108.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 95.8ms
# Speed: 2.9ms preprocess, 95.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 117.4ms
# Speed: 3.4ms preprocess, 117.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 111.5ms
# Speed: 3.5ms preprocess, 111.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 105.3ms
# Speed: 3.1ms preprocess, 105.3ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 107.0ms
# Speed: 3.2ms preprocess, 107.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 130.8ms
# Speed: 3.8ms preprocess, 130.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 113.6ms
# Speed: 4.6ms preprocess, 113.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 99.1ms
# Speed: 3.1ms preprocess, 99.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 104.2ms
# Speed: 4.3ms preprocess, 104.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 129.1ms
# Speed: 4.0ms preprocess, 129.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 113.7ms
# Speed: 3.1ms preprocess, 113.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 3 trucks, 100.5ms
# Speed: 4.8ms preprocess, 100.5ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 111.2ms
# Speed: 4.2ms preprocess, 111.2ms inference, 8.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 178.2ms
# Speed: 6.5ms preprocess, 178.2ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 148.4ms
# Speed: 4.3ms preprocess, 148.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 121.3ms
# Speed: 4.3ms preprocess, 121.3ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 108.8ms
# Speed: 4.2ms preprocess, 108.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 127.8ms
# Speed: 4.3ms preprocess, 127.8ms inference, 7.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 120.2ms
# Speed: 3.9ms preprocess, 120.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 116.4ms
# Speed: 3.9ms preprocess, 116.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 102.0ms
# Speed: 3.5ms preprocess, 102.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 126.5ms
# Speed: 3.9ms preprocess, 126.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 111.2ms
# Speed: 3.8ms preprocess, 111.2ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 114.1ms
# Speed: 3.7ms preprocess, 114.1ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 112.1ms
# Speed: 3.2ms preprocess, 112.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 128.6ms
# Speed: 5.1ms preprocess, 128.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 99.4ms
# Speed: 3.4ms preprocess, 99.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 91.6ms
# Speed: 4.1ms preprocess, 91.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 98.9ms
# Speed: 3.0ms preprocess, 98.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 111.2ms
# Speed: 4.9ms preprocess, 111.2ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 102.9ms
# Speed: 3.3ms preprocess, 102.9ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 112.7ms
# Speed: 2.9ms preprocess, 112.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 112.2ms
# Speed: 3.2ms preprocess, 112.2ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 139.3ms
# Speed: 3.5ms preprocess, 139.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 113.4ms
# Speed: 4.0ms preprocess, 113.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 104.5ms
# Speed: 3.5ms preprocess, 104.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 108.3ms
# Speed: 4.7ms preprocess, 108.3ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 130.9ms
# Speed: 5.1ms preprocess, 130.9ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 115.7ms
# Speed: 3.3ms preprocess, 115.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 102.0ms
# Speed: 4.1ms preprocess, 102.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 122.3ms
# Speed: 3.2ms preprocess, 122.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 153.6ms
# Speed: 3.7ms preprocess, 153.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 141.8ms
# Speed: 3.5ms preprocess, 141.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 113.2ms
# Speed: 3.6ms preprocess, 113.2ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 107.3ms
# Speed: 5.1ms preprocess, 107.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 149.1ms
# Speed: 3.9ms preprocess, 149.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 112.3ms
# Speed: 4.9ms preprocess, 112.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 108.7ms
# Speed: 3.4ms preprocess, 108.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 107.5ms
# Speed: 3.6ms preprocess, 107.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 116.8ms
# Speed: 3.6ms preprocess, 116.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 118.1ms
# Speed: 4.4ms preprocess, 118.1ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 106.0ms
# Speed: 3.6ms preprocess, 106.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 104.3ms
# Speed: 4.7ms preprocess, 104.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 115.2ms
# Speed: 3.8ms preprocess, 115.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 121.5ms
# Speed: 4.3ms preprocess, 121.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 104.3ms
# Speed: 3.3ms preprocess, 104.3ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 102.7ms
# Speed: 3.4ms preprocess, 102.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 102.7ms
# Speed: 236.5ms preprocess, 102.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 104.2ms
# Speed: 3.1ms preprocess, 104.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 121.5ms
# Speed: 3.3ms preprocess, 121.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 123.2ms
# Speed: 4.7ms preprocess, 123.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 103.9ms
# Speed: 3.4ms preprocess, 103.9ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 104.0ms
# Speed: 4.7ms preprocess, 104.0ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 128.3ms
# Speed: 4.0ms preprocess, 128.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 127.5ms
# Speed: 3.4ms preprocess, 127.5ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 100.5ms
# Speed: 4.6ms preprocess, 100.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 108.8ms
# Speed: 4.5ms preprocess, 108.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 122.1ms
# Speed: 3.5ms preprocess, 122.1ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 122.1ms
# Speed: 3.2ms preprocess, 122.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 3 trucks, 105.6ms
# Speed: 4.1ms preprocess, 105.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 152.3ms
# Speed: 5.0ms preprocess, 152.3ms inference, 7.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 138.0ms
# Speed: 4.0ms preprocess, 138.0ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 105.8ms
# Speed: 4.2ms preprocess, 105.8ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 3 trucks, 104.0ms
# Speed: 4.2ms preprocess, 104.0ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 123.5ms
# Speed: 4.9ms preprocess, 123.5ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 125.3ms
# Speed: 3.6ms preprocess, 125.3ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 105.7ms
# Speed: 3.2ms preprocess, 105.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 106.6ms
# Speed: 4.0ms preprocess, 106.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 128.3ms
# Speed: 4.0ms preprocess, 128.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 122.6ms
# Speed: 4.6ms preprocess, 122.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 104.3ms
# Speed: 3.4ms preprocess, 104.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 105.0ms
# Speed: 3.9ms preprocess, 105.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 123.3ms
# Speed: 4.6ms preprocess, 123.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 119.2ms
# Speed: 3.8ms preprocess, 119.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 105.4ms
# Speed: 3.6ms preprocess, 105.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 112.2ms
# Speed: 3.7ms preprocess, 112.2ms inference, 7.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 121.1ms
# Speed: 5.0ms preprocess, 121.1ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 112.6ms
# Speed: 3.6ms preprocess, 112.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 101.9ms
# Speed: 5.1ms preprocess, 101.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 114.3ms
# Speed: 4.1ms preprocess, 114.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 118.9ms
# Speed: 4.5ms preprocess, 118.9ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 111.3ms
# Speed: 5.6ms preprocess, 111.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 107.1ms
# Speed: 3.5ms preprocess, 107.1ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 117.5ms
# Speed: 3.5ms preprocess, 117.5ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 121.3ms
# Speed: 4.2ms preprocess, 121.3ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 148.2ms
# Speed: 3.6ms preprocess, 148.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 119.8ms
# Speed: 3.9ms preprocess, 119.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 115.8ms
# Speed: 3.7ms preprocess, 115.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 110.9ms
# Speed: 4.9ms preprocess, 110.9ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 105.7ms
# Speed: 4.6ms preprocess, 105.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 118.1ms
# Speed: 4.5ms preprocess, 118.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 115.6ms
# Speed: 3.5ms preprocess, 115.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 107.7ms
# Speed: 3.9ms preprocess, 107.7ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 109.2ms
# Speed: 3.8ms preprocess, 109.2ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 117.1ms
# Speed: 3.8ms preprocess, 117.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 122.2ms
# Speed: 3.6ms preprocess, 122.2ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 110.4ms
# Speed: 3.8ms preprocess, 110.4ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 104.5ms
# Speed: 3.4ms preprocess, 104.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 111.6ms
# Speed: 4.3ms preprocess, 111.6ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 119.9ms
# Speed: 4.6ms preprocess, 119.9ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 108.5ms
# Speed: 3.5ms preprocess, 108.5ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 108.1ms
# Speed: 4.3ms preprocess, 108.1ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 116.9ms
# Speed: 4.4ms preprocess, 116.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 123.5ms
# Speed: 3.7ms preprocess, 123.5ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 114.2ms
# Speed: 3.4ms preprocess, 114.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 107.0ms
# Speed: 3.3ms preprocess, 107.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 112.8ms
# Speed: 3.4ms preprocess, 112.8ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 130.2ms
# Speed: 4.2ms preprocess, 130.2ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 116.4ms
# Speed: 3.6ms preprocess, 116.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 108.1ms
# Speed: 4.0ms preprocess, 108.1ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 111.6ms
# Speed: 4.2ms preprocess, 111.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 125.3ms
# Speed: 3.6ms preprocess, 125.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 113.2ms
# Speed: 4.0ms preprocess, 113.2ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 116.9ms
# Speed: 3.3ms preprocess, 116.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 157.8ms
# Speed: 5.2ms preprocess, 157.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 119.9ms
# Speed: 3.4ms preprocess, 119.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 115.9ms
# Speed: 4.6ms preprocess, 115.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 112.9ms
# Speed: 4.8ms preprocess, 112.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 111.8ms
# Speed: 4.7ms preprocess, 111.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 121.2ms
# Speed: 3.2ms preprocess, 121.2ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 108.7ms
# Speed: 3.5ms preprocess, 108.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 105.0ms
# Speed: 3.3ms preprocess, 105.0ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 121.4ms
# Speed: 3.1ms preprocess, 121.4ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 121.0ms
# Speed: 3.7ms preprocess, 121.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 112.6ms
# Speed: 4.6ms preprocess, 112.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 103.2ms
# Speed: 3.4ms preprocess, 103.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 120.3ms
# Speed: 4.9ms preprocess, 120.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 113.1ms
# Speed: 4.9ms preprocess, 113.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 113.7ms
# Speed: 3.7ms preprocess, 113.7ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 102.9ms
# Speed: 3.8ms preprocess, 102.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 130.1ms
# Speed: 3.4ms preprocess, 130.1ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 116.9ms
# Speed: 4.8ms preprocess, 116.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 110.1ms
# Speed: 4.3ms preprocess, 110.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 100.6ms
# Speed: 4.1ms preprocess, 100.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 127.1ms
# Speed: 3.3ms preprocess, 127.1ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 113.8ms
# Speed: 5.1ms preprocess, 113.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 112.8ms
# Speed: 3.5ms preprocess, 112.8ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 102.7ms
# Speed: 4.9ms preprocess, 102.7ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 137.5ms
# Speed: 4.1ms preprocess, 137.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 112.6ms
# Speed: 4.7ms preprocess, 112.6ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 104.6ms
# Speed: 5.3ms preprocess, 104.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 159.0ms
# Speed: 4.3ms preprocess, 159.0ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 130.8ms
# Speed: 3.7ms preprocess, 130.8ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 117.8ms
# Speed: 4.0ms preprocess, 117.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 2 trucks, 105.3ms
# Speed: 4.4ms preprocess, 105.3ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 101.9ms
# Speed: 4.9ms preprocess, 101.9ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 133.9ms
# Speed: 4.2ms preprocess, 133.9ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 114.7ms
# Speed: 5.2ms preprocess, 114.7ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 103.2ms
# Speed: 4.3ms preprocess, 103.2ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 103.3ms
# Speed: 4.7ms preprocess, 103.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 135.0ms
# Speed: 4.5ms preprocess, 135.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 109.1ms
# Speed: 3.9ms preprocess, 109.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 104.1ms
# Speed: 3.8ms preprocess, 104.1ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 104.4ms
# Speed: 3.1ms preprocess, 104.4ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 2 trucks, 143.7ms
# Speed: 4.1ms preprocess, 143.7ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 107.0ms
# Speed: 4.6ms preprocess, 107.0ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 108.0ms
# Speed: 3.5ms preprocess, 108.0ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 108.7ms
# Speed: 5.2ms preprocess, 108.7ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 151.8ms
# Speed: 3.7ms preprocess, 151.8ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 109.2ms
# Speed: 5.1ms preprocess, 109.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 106.0ms
# Speed: 3.8ms preprocess, 106.0ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 115.5ms
# Speed: 5.3ms preprocess, 115.5ms inference, 6.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 2 trucks, 130.2ms
# Speed: 3.7ms preprocess, 130.2ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 106.6ms
# Speed: 4.3ms preprocess, 106.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 2 trucks, 106.9ms
# Speed: 3.8ms preprocess, 106.9ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 122.8ms
# Speed: 4.2ms preprocess, 122.8ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 117.3ms
# Speed: 5.5ms preprocess, 117.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 103.2ms
# Speed: 4.7ms preprocess, 103.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 truck, 105.8ms
# Speed: 4.6ms preprocess, 105.8ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 119.4ms
# Speed: 3.4ms preprocess, 119.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 165.3ms
# Speed: 3.9ms preprocess, 165.3ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 117.6ms
# Speed: 3.8ms preprocess, 117.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 125.8ms
# Speed: 3.3ms preprocess, 125.8ms inference, 7.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 103.6ms
# Speed: 5.0ms preprocess, 103.6ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 122.3ms
# Speed: 3.0ms preprocess, 122.3ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 115.5ms
# Speed: 4.0ms preprocess, 115.5ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 127.1ms
# Speed: 3.8ms preprocess, 127.1ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 103.9ms
# Speed: 4.0ms preprocess, 103.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 121.3ms
# Speed: 4.9ms preprocess, 121.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 129.5ms
# Speed: 4.4ms preprocess, 129.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 121.9ms
# Speed: 4.8ms preprocess, 121.9ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 114.6ms
# Speed: 4.5ms preprocess, 114.6ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 116.3ms
# Speed: 4.6ms preprocess, 116.3ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 120.3ms
# Speed: 4.8ms preprocess, 120.3ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 102.3ms
# Speed: 4.8ms preprocess, 102.3ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 123.3ms
# Speed: 4.3ms preprocess, 123.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 112.0ms
# Speed: 4.9ms preprocess, 112.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 123.8ms
# Speed: 4.6ms preprocess, 123.8ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 108.5ms
# Speed: 3.3ms preprocess, 108.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 121.3ms
# Speed: 3.1ms preprocess, 121.3ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 122.3ms
# Speed: 3.7ms preprocess, 122.3ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 114.7ms
# Speed: 5.5ms preprocess, 114.7ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 108.3ms
# Speed: 3.3ms preprocess, 108.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 122.5ms
# Speed: 5.2ms preprocess, 122.5ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 158.0ms
# Speed: 8.2ms preprocess, 158.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 114.3ms
# Speed: 4.5ms preprocess, 114.3ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 124.5ms
# Speed: 3.7ms preprocess, 124.5ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 109.4ms
# Speed: 4.9ms preprocess, 109.4ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 123.8ms
# Speed: 3.4ms preprocess, 123.8ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 109.8ms
# Speed: 3.4ms preprocess, 109.8ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 120.4ms
# Speed: 6.4ms preprocess, 120.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 107.3ms
# Speed: 4.2ms preprocess, 107.3ms inference, 5.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 120.4ms
# Speed: 3.6ms preprocess, 120.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 112.1ms
# Speed: 5.8ms preprocess, 112.1ms inference, 5.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 118.8ms
# Speed: 3.8ms preprocess, 118.8ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 112.6ms
# Speed: 3.3ms preprocess, 112.6ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 2 trucks, 124.2ms
# Speed: 4.8ms preprocess, 124.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 104.2ms
# Speed: 4.8ms preprocess, 104.2ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 118.2ms
# Speed: 3.9ms preprocess, 118.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 126.3ms
# Speed: 3.7ms preprocess, 126.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 109.2ms
# Speed: 3.7ms preprocess, 109.2ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 2 trucks, 116.8ms
# Speed: 4.9ms preprocess, 116.8ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 109.0ms
# Speed: 5.0ms preprocess, 109.0ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
# Results List (first 10 entries):
# [1, 1, 2, 0.0, 0.0, 13.156462290448752]
# [1, 1, 3, 0.0, 0.0, 19.95100248107849]
# [1, 1, 4, 0.0, 0.0, 16.945205811674285]
# [1, 1, 5, 0.0, 0.0, 14.637024970942697]
# [1, 1, 6, 0.0, 0.0, 22.828600482727804]
# [1, 1, 7, 0.0, 0.0, 34.40744832154805]
# [1, 1, 8, 0.0, 0.0, 26.474940981992763]
# [1, 1, 9, 0.0, 0.0, 26.487733009829288]
# [1, 1, 10, 0.0, 0.0, 39.52192429525668]
# [1, 1, 11, 0.0, 0.0, 30.491187251401023]

# %%
# Print results for verification
# [frame_no, vehicle_id1, vehicle_id2, speed1_kmh, speed2_kmh, distance_m]
print("Results List (first 20 entries):")
for r in results_list[:20]:
    print(r)
# Out:
# Results List (first 20 entries):
# [1, 1, 2, 0.0, 0.0, 13.156462290448752]
# [1, 1, 3, 0.0, 0.0, 19.95100248107849]
# [1, 1, 4, 0.0, 0.0, 16.945205811674285]
# [1, 1, 5, 0.0, 0.0, 14.637024970942697]
# [1, 1, 6, 0.0, 0.0, 22.828600482727804]
# [1, 1, 7, 0.0, 0.0, 34.40744832154805]
# [1, 1, 8, 0.0, 0.0, 26.474940981992763]
# [1, 1, 9, 0.0, 0.0, 26.487733009829288]
# [1, 1, 10, 0.0, 0.0, 39.52192429525668]
# [1, 1, 11, 0.0, 0.0, 30.491187251401023]
# [1, 2, 3, 0.0, 0.0, 9.104119946485767]
# [1, 2, 4, 0.0, 0.0, 19.628104849933933]
# [1, 2, 5, 0.0, 0.0, 10.20024509509453]
# [1, 2, 6, 0.0, 0.0, 10.925314640778087]
# [1, 2, 7, 0.0, 0.0, 22.004658597669724]
# [1, 2, 8, 0.0, 0.0, 14.057204558517316]
# [1, 2, 9, 0.0, 0.0, 14.058893982102575]
# [1, 2, 10, 0.0, 0.0, 27.02267566322773]
# [1, 2, 11, 0.0, 0.0, 17.971366113904644]
# [1, 3, 4, 0.0, 0.0, 18.29077636405847]

# %%
# Print results for verification
# [frame_no, vehicle_id1, vehicle_id2, speed1_kmh, speed2_kmh, distance_m]
print("Results List (Last 20 entries):")
for r in results_list[:-20:-1]:
    print(r)
# Out:
# Results List (Last 20 entries):
# [403, 231, 287, 9.0, 6.3639610306789285, 4.0388736053508785]
# [403, 285, 287, 0.0, 6.3639610306789285, 9.737812896128165]
# [403, 285, 231, 0.0, 9.0, 13.413146536141324]
# [403, 148, 287, 24.23324163210527, 6.3639610306789285, 20.523279465036772]
# [403, 148, 231, 24.23324163210527, 9.0, 17.84383647089381]
# [403, 148, 285, 24.23324163210527, 0.0, 30.0341472327749]
# [403, 272, 287, 6.3639610306789285, 6.3639610306789285, 5.01422975141746]
# [403, 272, 231, 6.3639610306789285, 9.0, 8.85353036929337]
# [403, 272, 285, 6.3639610306789285, 0.0, 4.759464255564906]
# [403, 272, 148, 6.3639610306789285, 24.23324163210527, 25.297677759035512]
# [403, 117, 287, 30.186917696247168, 6.3639610306789285, 45.29127951383136]
# [403, 117, 231, 30.186917696247168, 9.0, 42.12247025044947]
# [403, 117, 285, 30.186917696247168, 0.0, 54.95730160770269]
# [403, 117, 148, 30.186917696247168, 24.23324163210527, 25.075585735930478]
# [403, 117, 272, 30.186917696247168, 6.3639610306789285, 50.19912847849054]
# [403, 10, 287, 0.0, 6.3639610306789285, 9.737812896128165]
# [403, 10, 231, 0.0, 9.0, 13.413146536141324]
# [403, 10, 285, 0.0, 0.0, 0.0]
# [403, 10, 148, 0.0, 24.23324163210527, 30.0341472327749]

# %%
print(len(results_list))
# Out:
# 7883

# %%
count_blue_to_red
# Out:
# defaultdict(int, {})

# %%
count_red_to_blue
# Out:
# defaultdict(int, {'car': 9})

# %%
car = count_red_to_blue['car']
print(car)   

motorcycle = count_red_to_blue['motorcycle']
print(motorcycle)

truck = count_red_to_blue['truck']
print(truck)

ambulance=count_red_to_blue['ambulance']
print(ambulance)

bus=count_red_to_blue['bus']
print(bus)


actualcount={'car':car,'motorcycle':motorcycle,'truck':truck,'ambulance':ambulance}
print(actualcount)
# Out:
# 9
# 0
# 0
# 0
# 0
# {'car': 9, 'motorcycle': 0, 'truck': 0, 'ambulance': 0}

# %%
# ===============================
# Comprehensive Priority Score (CPS) Calculator
# ===============================

# -------------------------
# Tuning knobs (adjustable)
# -------------------------
# Percentage contributions (calibrated based on discussion)
TRAFFIC_CONTRIB = 0.65  # Part 1: Traffic Score
SAFETY_CONTRIB = 0.12   # Part 2: Safety Penalty
GREEN_WAVE_CONTRIB = 0.23  # Part 3: Green Wave Bonus

# Base weights for events
HARD_BRAKING_POINTS = 2
TAILGATING_POINTS = 1

# Max scale for ETA
MAX_ETA_SCALE = 6

# -------------------------
# Traffic class weights
# -------------------------
CLASS_WEIGHTS = {
    "ambulance": 12,
    "bus": 3.5,
    "truck": 2.5,
    "car": 1,
    "bike": 0.3
}

# -------------------------
# Part 1: Traffic Score
# -------------------------
carscore=1*car
ambulancescore=12*ambulance
bikescore=0.3*motorcycle
truckscore=2.5*truck
busscore=3.5*bus

traffic_score=carscore+bikescore+ambulancescore+truckscore+busscore

print("---- Traffic Score Calculator ----")

print("The traffic score is",traffic_score)
# Out:
# ---- Traffic Score Calculator ----
# The traffic score is 9.0

# %%
hard_brakes = []
prev_speeds = {}
brake_state = {}   # vehicle_id -> True agar gaadi abhi stop hai

for frame_no, id1, id2, v1, v2, dist in results_list:
    for vid, v in [(id1, v1), (id2, v2)]:

        # Agar pehle se speed stored hai
        if vid in prev_speeds:
            # Case: Pehle chal rahi thi (>0), abhi 0 → Hard Brake (sirf first stop par count)
            if prev_speeds[vid] > 0 and v == 0 and not brake_state.get(vid, False):
                hard_brakes.append((frame_no, vid, prev_speeds[vid]))
                brake_state[vid] = True   # abhi stop state me hai

            # Agar gaadi dobara chalne lagi toh reset stop-state
            elif v > 0:
                brake_state[vid] = False

        prev_speeds[vid] = v

# Duplicate hard brakes hatao (same vehicle ke multiple 0 ek hi stop me gaye hon)
unique_hard_brakes = {}
for frame_no, vid, speed in hard_brakes:
    if vid not in unique_hard_brakes:
        unique_hard_brakes[vid] = (frame_no, speed)

hard_braking_count = len(unique_hard_brakes)
print("Hard Braking Count:", hard_braking_count)
# Out:
# Hard Braking Count: 12

# %%
TAILGATE_DISTANCE = 10.0   # meters
MIN_SPEED = 20.0           # km/h
MIN_CONSEC_FRAMES = 5      # kitne consecutive frames me hona chahiye

pair_states = {}   # (id1,id2) -> consecutive frame counter
tailgates = []

for frame_no, id1, id2, v1, v2, dist in results_list:
    pair = tuple(sorted((id1, id2)))
    if dist <= TAILGATE_DISTANCE and v1 >= MIN_SPEED and v2 >= MIN_SPEED:
        # increase streak
        pair_states[pair] = pair_states.get(pair, 0) + 1
        # jab streak threshold paar kare to ek event count karo
        if pair_states[pair] == MIN_CONSEC_FRAMES:
            tailgates.append((frame_no, pair[0], pair[1], dist))
    else:
        pair_states[pair] = 0  # streak reset

tailgating_count = len(tailgates)
print("Tailgating Count:", tailgating_count)
# Out:
# Tailgating Count: 5
